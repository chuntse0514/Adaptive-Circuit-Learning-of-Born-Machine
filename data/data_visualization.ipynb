# %%
from data import DATA_HUB
import matplotlib.pyplot as plt
import numpy as np

# %%
log_normal_3_pmf = DATA_HUB['log normal 3'].get_data()
k = np.arange(8)

plt.bar(k, log_normal_3_pmf)
plt.show()

# %%
log_normal_10_pmf = DATA_HUB['log normal 10'].get_data()
k = np.arange(1024)

plt.bar(k, log_normal_10_pmf)
plt.show()

# %%
bimodal_3_pmf = DATA_HUB['bimodal 3'].get_data()
k = np.arange(8)

plt.bar(k, bimodal_3_pmf)
plt.show()

# %%
bimodal_10_pmf = DATA_HUB['bimodal 10'].get_data()
k = np.arange(1024)

plt.bar(k, bimodal_10_pmf)
plt.show()

# %%
triangular_3_pmf = DATA_HUB['triangular 3'].get_data()
k = np.arange(8)

plt.bar(k, triangular_3_pmf)
plt.show()

# %%
triangular_10_pmf = DATA_HUB['triangular 10'].get_data()
k = np.arange(1024)

plt.bar(k, triangular_10_pmf)
plt.show()

# %%
bas_2x2_pmf = DATA_HUB['bas 2x2'].get_data()
k = np.arange(16)

plt.bar(k, bas_2x2_pmf)
plt.show()

# %%
bas_3x3_pmf = DATA_HUB['bas 3x3'].get_data()
k = np.arange(512)

plt.figure(figsize=(10,5))

plt.bar(k, bas_3x3_pmf, width=3)
plt.show()

# %%
bas_4x4_pmf = DATA_HUB['bas 4x4'].get_data()
k = np.arange(65536)

plt.figure(figsize=(10,5))

plt.bar(k, bas_4x4_pmf, width=200)
plt.show()

# %%
real_image_1_pmf = DATA_HUB['real image 1'].get_data()
k = np.arange(65536)

plt.imshow(real_image_1_pmf.reshape(256, 256))
plt.show()

# %%
real_image_2_pmf = DATA_HUB['real image 2'].get_data()
k = np.arange(65536)

plt.imshow(real_image_2_pmf.reshape(256, 256))
plt.show()

# %%
real_image_3_pmf = DATA_HUB['real image 3'].get_data()
k = np.arange(65536)

plt.imshow(real_image_3_pmf.reshape(256, 256))
plt.show()
